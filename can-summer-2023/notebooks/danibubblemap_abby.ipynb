# %%
#temporary seperate import until plotly install issue is addressed.
import pandas as pd

# %%
#importing dependencies for workbook
import pandas as pd
import plotly.express as px

# %%
#importing csv files for computing branch metrics and branch locations
branchMetrics = pd.read_csv('../can-summer-2023/data/clean/branch_metrics.csv')
branchLocations = pd.read_csv('../can-summer-2023/data/clean/branches.csv')

#checking branchMetrics
branchMetrics.head()
# Out:
#         BRANCH  YEAR  MONTH  CIRCULATION  COMPUTER_SESSIONS  VISITORS
# 0  Albany Park  2011      1       8427.0             1666.0    9604.0
# 1  Albany Park  2011      2       7023.0             1296.0   10500.0
# 2  Albany Park  2011      3       9702.0             1735.0    9050.0
# 3  Albany Park  2011      4       9344.0             1841.0    9300.0
# 4  Albany Park  2011      5       8865.0             1683.0    8271.0

# %%
#checking branchLocations
branchLocations.head()
# Out:
#            BRANCH                                 HOURS OF OPERATION  \
# 0     Albany Park  Mon. & Wed., 10-6; Tues. & Thurs., Noon-8; Fri...
# 1         Altgeld  Mon. & Wed., Noon-8; Tues. & Thurs., 10-6; Fri...
# 2  Archer Heights  Mon. & Wed., Noon-8; Tues. & Thurs., 10-6; Fri...
# 3          Austin  Mon. & Wed., Noon-8; Tues. & Thurs., 10-6; Fri...
# 4   Austin-Irving  Mon. & Wed., Noon-8; Tues. & Thurs., 10-6; Fri...
#
#                    ADDRESS     CITY STATE    ZIP           PHONE  \
# 0      3401 W. Foster Ave.  Chicago    IL  60625  (773) 539-5450
# 1      955 E. 131st Street  Chicago    IL  60827  (312) 747-3270
# 2      5055 S. Archer Ave.  Chicago    IL  60632  (312) 747-9241
# 3        5615 W. Race Ave.  Chicago    IL  60644  (312) 746-5038
# 4  6100 W. Irving Park Rd.  Chicago    IL  60634  (312) 744-6222
#
#                                   WEBSITE  \
# 0  https://www.chipublib.org/locations/3/
# 1  https://www.chipublib.org/locations/4/
# 2  https://www.chipublib.org/locations/5/
# 3  https://www.chipublib.org/locations/6/
# 4  https://www.chipublib.org/locations/7/
#
#                                   LOCATION  PERMANENTLY_CLOSED
# 0  (41.97557881655979, -87.71361314512697)                   0
# 1  (41.65719847558056, -87.59883829075173)                   0
# 2  (41.80110836194246, -87.72648385568911)                   0
# 3   (41.88917312206642, -87.7658203582574)                   0
# 4  (41.95312267684315, -87.77928489355646)                   0

# %%
#Removing rows with no data
#checking shape before dropping na values
print(branchMetrics.shape)
branchMetrics = branchMetrics.dropna(subset = ['COMPUTER_SESSIONS', 'VISITORS'])
#checking data after dropping na values for computer and visitors column. 
branchMetrics
# Out:
# (11880, 6)
#                    BRANCH  YEAR  MONTH  CIRCULATION  COMPUTER_SESSIONS  \
# 0             Albany Park  2011      1       8427.0             1666.0
# 1             Albany Park  2011      2       7023.0             1296.0
# 2             Albany Park  2011      3       9702.0             1735.0
# 3             Albany Park  2011      4       9344.0             1841.0
# 4             Albany Park  2011      5       8865.0             1683.0
# ...                   ...   ...    ...          ...                ...
# 11875  Wrightwood-Ashburn  2022     12        575.0              511.0
# 11876  Wrightwood-Ashburn  2023      1        658.0              577.0
# 11877  Wrightwood-Ashburn  2023      2        683.0              561.0
# 11878  Wrightwood-Ashburn  2023      3        834.0              806.0
# 11879  Wrightwood-Ashburn  2023      4       1038.0              757.0
#
#        VISITORS
# 0        9604.0
# 1       10500.0
# 2        9050.0
# 3        9300.0
# 4        8271.0
# ...         ...
# 11875    1410.0
# 11876    1625.0
# 11877   12146.0
# 11878    6312.0
# 11879    4074.0
#
# [11711 rows x 6 columns]

# %%
#Removing rows with 0 in the COMPUTER_SESSIOONS and VISITORS column
branchMetrics = branchMetrics[(branchMetrics['VISITORS'] > 0) & (branchMetrics['COMPUTER_SESSIONS'] > 0)]
branchMetrics
# Out:
#                    BRANCH  YEAR  MONTH  CIRCULATION  COMPUTER_SESSIONS  \
# 0             Albany Park  2011      1       8427.0             1666.0
# 1             Albany Park  2011      2       7023.0             1296.0
# 2             Albany Park  2011      3       9702.0             1735.0
# 3             Albany Park  2011      4       9344.0             1841.0
# 4             Albany Park  2011      5       8865.0             1683.0
# ...                   ...   ...    ...          ...                ...
# 11875  Wrightwood-Ashburn  2022     12        575.0              511.0
# 11876  Wrightwood-Ashburn  2023      1        658.0              577.0
# 11877  Wrightwood-Ashburn  2023      2        683.0              561.0
# 11878  Wrightwood-Ashburn  2023      3        834.0              806.0
# 11879  Wrightwood-Ashburn  2023      4       1038.0              757.0
#
#        VISITORS
# 0        9604.0
# 1       10500.0
# 2        9050.0
# 3        9300.0
# 4        8271.0
# ...         ...
# 11875    1410.0
# 11876    1625.0
# 11877   12146.0
# 11878    6312.0
# 11879    4074.0
#
# [11065 rows x 6 columns]

# %%
branchMetrics.BRANCH.unique().size
# Out:
# 81

# %%
#getting sums of Circulation, Computer_Sessions, and Visitors in each branch by year
metricsByYear = branchMetrics.groupby(['YEAR','BRANCH']).sum()
metricsByYear
# Out:
#                             MONTH  CIRCULATION  COMPUTER_SESSIONS  VISITORS
# YEAR BRANCH
# 2011 Albany Park               78     120059.0            21966.0  117425.0
#      Altgeld                   78       9611.0            31782.0   58657.0
#      Archer Heights            78     101951.0            25321.0  124653.0
#      Austin                    78      25527.0            33207.0  102306.0
#      Austin-Irving             78     165634.0            35093.0  145852.0
# ...                           ...          ...                ...       ...
# 2023 West Pullman              10       3325.0             4629.0   23966.0
#      West Town                 10      18885.0             4329.0   29180.0
#      Whitney M. Young, Jr.     10       3068.0             6402.0   14232.0
#      Woodson Regional          10       8480.0            12663.0   24108.0
#      Wrightwood-Ashburn        10       3213.0             2701.0   24157.0
#
# [1012 rows x 4 columns]

# %%
#Resetting the index for metricsByYear and mergind with location data
metricsByYear.reset_index(inplace = True)
metricsByYear
# Out:
#       YEAR                 BRANCH  MONTH  CIRCULATION  COMPUTER_SESSIONS  \
# 0     2011            Albany Park     78     120059.0            21966.0
# 1     2011                Altgeld     78       9611.0            31782.0
# 2     2011         Archer Heights     78     101951.0            25321.0
# 3     2011                 Austin     78      25527.0            33207.0
# 4     2011          Austin-Irving     78     165634.0            35093.0
# ...    ...                    ...    ...          ...                ...
# 1007  2023           West Pullman     10       3325.0             4629.0
# 1008  2023              West Town     10      18885.0             4329.0
# 1009  2023  Whitney M. Young, Jr.     10       3068.0             6402.0
# 1010  2023       Woodson Regional     10       8480.0            12663.0
# 1011  2023     Wrightwood-Ashburn     10       3213.0             2701.0
#
#       VISITORS
# 0     117425.0
# 1      58657.0
# 2     124653.0
# 3     102306.0
# 4     145852.0
# ...        ...
# 1007   23966.0
# 1008   29180.0
# 1009   14232.0
# 1010   24108.0
# 1011   24157.0
#
# [1012 rows x 6 columns]

# %%
metricsByYear.BRANCH.unique().size
# Out:
# 81

# %%
metricsByYear = metricsByYear.merge(branchLocations)
metricsByYear
# Out:
#      YEAR       BRANCH  MONTH  CIRCULATION  COMPUTER_SESSIONS  VISITORS  \
# 0    2011  Albany Park     78     120059.0            21966.0  117425.0
# 1    2012  Albany Park     45      83192.0            15423.0   78485.0
# 2    2014  Albany Park     42      50260.0             9546.0   53058.0
# 3    2015  Albany Park     78     133366.0            37114.0  153751.0
# 4    2016  Albany Park     78     135858.0            37025.0  159397.0
# ..    ...          ...    ...          ...                ...       ...
# 995  2022    West Loop     78      52688.0             4784.0   51137.0
# 996  2023    West Loop     10      18737.0             1637.0   23173.0
# 997  2021  Water Works     42       8516.0              306.0   10594.0
# 998  2022  Water Works     77      35804.0             1864.0   47594.0
# 999  2023  Water Works     10      11988.0              648.0   15985.0
#
#                                     HOURS OF OPERATION              ADDRESS  \
# 0    Mon. & Wed., 10-6; Tues. & Thurs., Noon-8; Fri...  3401 W. Foster Ave.
# 1    Mon. & Wed., 10-6; Tues. & Thurs., Noon-8; Fri...  3401 W. Foster Ave.
# 2    Mon. & Wed., 10-6; Tues. & Thurs., Noon-8; Fri...  3401 W. Foster Ave.
# 3    Mon. & Wed., 10-6; Tues. & Thurs., Noon-8; Fri...  3401 W. Foster Ave.
# 4    Mon. & Wed., 10-6; Tues. & Thurs., Noon-8; Fri...  3401 W. Foster Ave.
# ..                                                 ...                  ...
# 995  Mon. & Wed., 10-6; Tues. & Thurs., Noon-8; Fri...  122 N. Aberdeen St.
# 996  Mon. & Wed., 10-6; Tues. & Thurs., Noon-8; Fri...  122 N. Aberdeen St.
# 997   Mon. - Thurs., 10-6; Fri. & Sat., 9-5; Sun., 1-5   163 E. Pearson St.
# 998   Mon. - Thurs., 10-6; Fri. & Sat., 9-5; Sun., 1-5   163 E. Pearson St.
# 999   Mon. - Thurs., 10-6; Fri. & Sat., 9-5; Sun., 1-5   163 E. Pearson St.
#
#         CITY STATE    ZIP           PHONE  \
# 0    Chicago    IL  60625  (773) 539-5450
# 1    Chicago    IL  60625  (773) 539-5450
# 2    Chicago    IL  60625  (773) 539-5450
# 3    Chicago    IL  60625  (773) 539-5450
# 4    Chicago    IL  60625  (773) 539-5450
# ..       ...   ...    ...             ...
# 995  Chicago    IL  60607  (312) 744-2995
# 996  Chicago    IL  60607  (312) 744-2995
# 997  Chicago    IL  60611  (312) 742-8811
# 998  Chicago    IL  60611  (312) 742-8811
# 999  Chicago    IL  60611  (312) 742-8811
#
#                                      WEBSITE  \
# 0     https://www.chipublib.org/locations/3/
# 1     https://www.chipublib.org/locations/3/
# 2     https://www.chipublib.org/locations/3/
# 3     https://www.chipublib.org/locations/3/
# 4     https://www.chipublib.org/locations/3/
# ..                                       ...
# 995  https://www.chipublib.org/locations/88/
# 996  https://www.chipublib.org/locations/88/
# 997  https://www.chipublib.org/locations/73/
# 998  https://www.chipublib.org/locations/73/
# 999  https://www.chipublib.org/locations/73/
#
#                                      LOCATION  PERMANENTLY_CLOSED
# 0     (41.97557881655979, -87.71361314512697)                   0
# 1     (41.97557881655979, -87.71361314512697)                   0
# 2     (41.97557881655979, -87.71361314512697)                   0
# 3     (41.97557881655979, -87.71361314512697)                   0
# 4     (41.97557881655979, -87.71361314512697)                   0
# ..                                        ...                 ...
# 995     (41.8837105009142, -87.6545650515331)                   0
# 996     (41.8837105009142, -87.6545650515331)                   0
# 997  (41.897484072390675, -87.62337776811282)                   0
# 998  (41.897484072390675, -87.62337776811282)                   0
# 999  (41.897484072390675, -87.62337776811282)                   0
#
# [1000 rows x 15 columns]

# %%
metricsByYear.BRANCH.unique().size
# Out:
# 80

# %%
#The groupby year and branch data seems to leave out one branch, so we are determining which is left out. I found that Woodson Regional
#was left out because it is called Woodson Regional Library in the branch_metrics.csv and therefore it was lost during the merge.metricsByYear.BRANCH.unique().size
list(set(branchMetrics.BRANCH.unique()) - set(metricsByYear.BRANCH.unique()))
# Out:
# ['Woodson Regional']

# %%
#Checking branch names before replacing
branchMetrics.BRANCH.unique()
# Out:
# array(['Albany Park', 'Altgeld', 'Archer Heights', 'Austin',
#        'Austin-Irving', 'Avalon', 'Back of the Yards', 'Beverly',
#        'Bezazian', 'Blackstone', 'Brainerd', 'Brighton Park',
#        'Bucktown-Wicker Park', 'Budlong Woods', 'Canaryville',
#        'Chicago Bee', 'Chicago Lawn', 'Chinatown', 'Clearing', 'Coleman',
#        'Daley, Richard J. - Bridgeport',
#        'Daley, Richard M. - W. Humboldt', 'Douglass', 'Dunning',
#        'Edgebrook', 'Edgewater', 'Gage Park', 'Garfield Ridge',
#        'Greater Grand Crossing', 'Hall',
#        'Harold Washington Library Center', 'Hegewisch', 'Humboldt Park',
#        'Independence', 'Jefferson Park', 'Jeffery Manor', 'Kelly', 'King',
#        'Legler Regional', 'Lincoln Belmont', 'Lincoln Park',
#        'Little Italy', 'Little Village', 'Logan Square', 'Lozano',
#        'Manning', 'Mayfair', 'McKinley Park', 'Merlo', 'Mount Greenwood',
#        'Near North', 'North Austin', 'North Pulaski', 'Northtown',
#        'Oriole Park', 'Portage-Cragin', 'Pullman', 'Roden', 'Rogers Park',
#        'Roosevelt', 'Scottsdale', 'Sherman Park', 'South Chicago',
#        'South Shore', 'Sulzer Regional', 'Thurgood Marshall', 'Toman',
#        'Uptown', 'Vodak-East Side', 'Walker', 'Water Works',
#        'West Belmont', 'West Chicago Avenue', 'West Englewood',
#        'West Lawn', 'West Loop', 'West Pullman', 'West Town',
#        'Whitney M. Young, Jr.', 'Woodson Regional', 'Wrightwood-Ashburn'],
#       dtype=object)

# %%
#replacing the branch name
branchMetrics.loc[branchMetrics.BRANCH == 'Woodson Regional', 'BRANCH'] = 'Woodson Regional Library'
branchMetrics.BRANCH.unique()
# Out:
# array(['Albany Park', 'Altgeld', 'Archer Heights', 'Austin',
#        'Austin-Irving', 'Avalon', 'Back of the Yards', 'Beverly',
#        'Bezazian', 'Blackstone', 'Brainerd', 'Brighton Park',
#        'Bucktown-Wicker Park', 'Budlong Woods', 'Canaryville',
#        'Chicago Bee', 'Chicago Lawn', 'Chinatown', 'Clearing', 'Coleman',
#        'Daley, Richard J. - Bridgeport',
#        'Daley, Richard M. - W. Humboldt', 'Douglass', 'Dunning',
#        'Edgebrook', 'Edgewater', 'Gage Park', 'Garfield Ridge',
#        'Greater Grand Crossing', 'Hall',
#        'Harold Washington Library Center', 'Hegewisch', 'Humboldt Park',
#        'Independence', 'Jefferson Park', 'Jeffery Manor', 'Kelly', 'King',
#        'Legler Regional', 'Lincoln Belmont', 'Lincoln Park',
#        'Little Italy', 'Little Village', 'Logan Square', 'Lozano',
#        'Manning', 'Mayfair', 'McKinley Park', 'Merlo', 'Mount Greenwood',
#        'Near North', 'North Austin', 'North Pulaski', 'Northtown',
#        'Oriole Park', 'Portage-Cragin', 'Pullman', 'Roden', 'Rogers Park',
#        'Roosevelt', 'Scottsdale', 'Sherman Park', 'South Chicago',
#        'South Shore', 'Sulzer Regional', 'Thurgood Marshall', 'Toman',
#        'Uptown', 'Vodak-East Side', 'Walker', 'Water Works',
#        'West Belmont', 'West Chicago Avenue', 'West Englewood',
#        'West Lawn', 'West Loop', 'West Pullman', 'West Town',
#        'Whitney M. Young, Jr.', 'Woodson Regional Library',
#        'Wrightwood-Ashburn'], dtype=object)

# %%
#metricsByYear needs to be recreated so we can recover the data lost before the merge.
metricsByYear = branchMetrics.groupby(['YEAR','BRANCH']).sum()
metricsByYear.reset_index(inplace = True)
metricsByYear = metricsByYear.merge(branchLocations)
#Making sure there are 81 branches represented
metricsByYear.BRANCH.unique().size
metricsByYear.head(24)
# Out:
#     YEAR       BRANCH  MONTH  CIRCULATION  COMPUTER_SESSIONS  VISITORS  \
# 0   2011  Albany Park     78     120059.0            21966.0  117425.0
# 1   2012  Albany Park     45      83192.0            15423.0   78485.0
# 2   2014  Albany Park     42      50260.0             9546.0   53058.0
# 3   2015  Albany Park     78     133366.0            37114.0  153751.0
# 4   2016  Albany Park     78     135858.0            37025.0  159397.0
# 5   2017  Albany Park     78     121534.0            30645.0  157976.0
# 6   2018  Albany Park     78     111168.0            26720.0  151560.0
# 7   2019  Albany Park     78      93009.0            23279.0  130255.0
# 8   2020  Albany Park     69      49247.0             7370.0   52199.0
# 9   2021  Albany Park     78      61634.0             8838.0   62840.0
# 10  2022  Albany Park     78      64486.0            13089.0   79075.0
# 11  2023  Albany Park     10      21369.0             4183.0   27586.0
# 12  2011      Altgeld     78       9611.0            31782.0   58657.0
# 13  2012      Altgeld     78      10010.0            38040.0   62058.0
# 14  2013      Altgeld     78       9518.0            34407.0   63052.0
# 15  2014      Altgeld     78       8509.0            31304.0   61270.0
# 16  2015      Altgeld     78       6382.0            23460.0   58248.0
# 17  2016      Altgeld     78       5864.0            18826.0   57479.0
# 18  2017      Altgeld     78       4297.0            12098.0   38428.0
# 19  2018      Altgeld     78       4469.0             8531.0   32763.0
# 20  2019      Altgeld     78       4014.0             5226.0   28196.0
# 21  2020      Altgeld      6        779.0              618.0    5666.0
# 22  2021      Altgeld     78       1934.0             6719.0   10760.0
# 23  2022      Altgeld     78       2641.0            11282.0   38946.0
#
#                                    HOURS OF OPERATION              ADDRESS  \
# 0   Mon. & Wed., 10-6; Tues. & Thurs., Noon-8; Fri...  3401 W. Foster Ave.
# 1   Mon. & Wed., 10-6; Tues. & Thurs., Noon-8; Fri...  3401 W. Foster Ave.
# 2   Mon. & Wed., 10-6; Tues. & Thurs., Noon-8; Fri...  3401 W. Foster Ave.
# 3   Mon. & Wed., 10-6; Tues. & Thurs., Noon-8; Fri...  3401 W. Foster Ave.
# 4   Mon. & Wed., 10-6; Tues. & Thurs., Noon-8; Fri...  3401 W. Foster Ave.
# 5   Mon. & Wed., 10-6; Tues. & Thurs., Noon-8; Fri...  3401 W. Foster Ave.
# 6   Mon. & Wed., 10-6; Tues. & Thurs., Noon-8; Fri...  3401 W. Foster Ave.
# 7   Mon. & Wed., 10-6; Tues. & Thurs., Noon-8; Fri...  3401 W. Foster Ave.
# 8   Mon. & Wed., 10-6; Tues. & Thurs., Noon-8; Fri...  3401 W. Foster Ave.
# 9   Mon. & Wed., 10-6; Tues. & Thurs., Noon-8; Fri...  3401 W. Foster Ave.
# 10  Mon. & Wed., 10-6; Tues. & Thurs., Noon-8; Fri...  3401 W. Foster Ave.
# 11  Mon. & Wed., 10-6; Tues. & Thurs., Noon-8; Fri...  3401 W. Foster Ave.
# 12  Mon. & Wed., Noon-8; Tues. & Thurs., 10-6; Fri...  955 E. 131st Street
# 13  Mon. & Wed., Noon-8; Tues. & Thurs., 10-6; Fri...  955 E. 131st Street
# 14  Mon. & Wed., Noon-8; Tues. & Thurs., 10-6; Fri...  955 E. 131st Street
# 15  Mon. & Wed., Noon-8; Tues. & Thurs., 10-6; Fri...  955 E. 131st Street
# 16  Mon. & Wed., Noon-8; Tues. & Thurs., 10-6; Fri...  955 E. 131st Street
# 17  Mon. & Wed., Noon-8; Tues. & Thurs., 10-6; Fri...  955 E. 131st Street
# 18  Mon. & Wed., Noon-8; Tues. & Thurs., 10-6; Fri...  955 E. 131st Street
# 19  Mon. & Wed., Noon-8; Tues. & Thurs., 10-6; Fri...  955 E. 131st Street
# 20  Mon. & Wed., Noon-8; Tues. & Thurs., 10-6; Fri...  955 E. 131st Street
# 21  Mon. & Wed., Noon-8; Tues. & Thurs., 10-6; Fri...  955 E. 131st Street
# 22  Mon. & Wed., Noon-8; Tues. & Thurs., 10-6; Fri...  955 E. 131st Street
# 23  Mon. & Wed., Noon-8; Tues. & Thurs., 10-6; Fri...  955 E. 131st Street
#
#        CITY STATE    ZIP           PHONE  \
# 0   Chicago    IL  60625  (773) 539-5450
# 1   Chicago    IL  60625  (773) 539-5450
# 2   Chicago    IL  60625  (773) 539-5450
# 3   Chicago    IL  60625  (773) 539-5450
# 4   Chicago    IL  60625  (773) 539-5450
# 5   Chicago    IL  60625  (773) 539-5450
# 6   Chicago    IL  60625  (773) 539-5450
# 7   Chicago    IL  60625  (773) 539-5450
# 8   Chicago    IL  60625  (773) 539-5450
# 9   Chicago    IL  60625  (773) 539-5450
# 10  Chicago    IL  60625  (773) 539-5450
# 11  Chicago    IL  60625  (773) 539-5450
# 12  Chicago    IL  60827  (312) 747-3270
# 13  Chicago    IL  60827  (312) 747-3270
# 14  Chicago    IL  60827  (312) 747-3270
# 15  Chicago    IL  60827  (312) 747-3270
# 16  Chicago    IL  60827  (312) 747-3270
# 17  Chicago    IL  60827  (312) 747-3270
# 18  Chicago    IL  60827  (312) 747-3270
# 19  Chicago    IL  60827  (312) 747-3270
# 20  Chicago    IL  60827  (312) 747-3270
# 21  Chicago    IL  60827  (312) 747-3270
# 22  Chicago    IL  60827  (312) 747-3270
# 23  Chicago    IL  60827  (312) 747-3270
#
#                                    WEBSITE  \
# 0   https://www.chipublib.org/locations/3/
# 1   https://www.chipublib.org/locations/3/
# 2   https://www.chipublib.org/locations/3/
# 3   https://www.chipublib.org/locations/3/
# 4   https://www.chipublib.org/locations/3/
# 5   https://www.chipublib.org/locations/3/
# 6   https://www.chipublib.org/locations/3/
# 7   https://www.chipublib.org/locations/3/
# 8   https://www.chipublib.org/locations/3/
# 9   https://www.chipublib.org/locations/3/
# 10  https://www.chipublib.org/locations/3/
# 11  https://www.chipublib.org/locations/3/
# 12  https://www.chipublib.org/locations/4/
# 13  https://www.chipublib.org/locations/4/
# 14  https://www.chipublib.org/locations/4/
# 15  https://www.chipublib.org/locations/4/
# 16  https://www.chipublib.org/locations/4/
# 17  https://www.chipublib.org/locations/4/
# 18  https://www.chipublib.org/locations/4/
# 19  https://www.chipublib.org/locations/4/
# 20  https://www.chipublib.org/locations/4/
# 21  https://www.chipublib.org/locations/4/
# 22  https://www.chipublib.org/locations/4/
# 23  https://www.chipublib.org/locations/4/
#
#                                    LOCATION  PERMANENTLY_CLOSED
# 0   (41.97557881655979, -87.71361314512697)                   0
# 1   (41.97557881655979, -87.71361314512697)                   0
# 2   (41.97557881655979, -87.71361314512697)                   0
# 3   (41.97557881655979, -87.71361314512697)                   0
# 4   (41.97557881655979, -87.71361314512697)                   0
# 5   (41.97557881655979, -87.71361314512697)                   0
# 6   (41.97557881655979, -87.71361314512697)                   0
# 7   (41.97557881655979, -87.71361314512697)                   0
# 8   (41.97557881655979, -87.71361314512697)                   0
# 9   (41.97557881655979, -87.71361314512697)                   0
# 10  (41.97557881655979, -87.71361314512697)                   0
# 11  (41.97557881655979, -87.71361314512697)                   0
# 12  (41.65719847558056, -87.59883829075173)                   0
# 13  (41.65719847558056, -87.59883829075173)                   0
# 14  (41.65719847558056, -87.59883829075173)                   0
# 15  (41.65719847558056, -87.59883829075173)                   0
# 16  (41.65719847558056, -87.59883829075173)                   0
# 17  (41.65719847558056, -87.59883829075173)                   0
# 18  (41.65719847558056, -87.59883829075173)                   0
# 19  (41.65719847558056, -87.59883829075173)                   0
# 20  (41.65719847558056, -87.59883829075173)                   0
# 21  (41.65719847558056, -87.59883829075173)                   0
# 22  (41.65719847558056, -87.59883829075173)                   0
# 23  (41.65719847558056, -87.59883829075173)                   0

# %%
#Dropping unnecessary data
metricsByYear = metricsByYear[['YEAR', 'BRANCH', 'CIRCULATION', 'COMPUTER_SESSIONS', 'VISITORS', 'LOCATION']]
metricsByYear.sort_values(by='YEAR', ascending=True, inplace=True)
metricsByYear
# Out:
#       YEAR                           BRANCH  CIRCULATION  COMPUTER_SESSIONS  \
# 0     2011                      Albany Park     120059.0            21966.0
# 681   2011                      Oriole Park     139626.0            17721.0
# 232   2011                         Clearing      77943.0            20401.0
# 694   2011                   Portage-Cragin     118133.0            24273.0
# 707   2011                          Pullman      25807.0            22283.0
# ...    ...                              ...          ...                ...
# 283   2023  Daley, Richard M. - W. Humboldt       4815.0             3878.0
# 615   2023                            Merlo      36653.0             4108.0
# 50    2023                           Austin       2959.0             3187.0
# 295   2023                         Douglass       1266.0             2639.0
# 1011  2023                      Water Works      11988.0              648.0
#
#       VISITORS                                  LOCATION
# 0     117425.0   (41.97557881655979, -87.71361314512697)
# 681   139799.0  (41.978098111742476, -87.81420029973704)
# 232   109231.0  (41.776652677565934, -87.78218757614671)
# 694   112283.0   (41.93883597361448, -87.75467117455794)
# 707    80816.0    (41.69436481773882, -87.6181414059763)
# ...        ...                                       ...
# 283    17469.0   (41.894726658545295, -87.7063841773407)
# 615    46193.0  (41.940131637508564, -87.64602857926714)
# 50     14753.0    (41.88917312206642, -87.7658203582574)
# 295     6104.0   (41.86441239309047, -87.71017465670012)
# 1011   15985.0  (41.897484072390675, -87.62337776811282)
#
# [1012 rows x 6 columns]

# %%
#Replacing Location with longitude and latitude columns
import ast
metricsByYear[['LATITUDE', 'LONGITUDE']] = [ast.literal_eval(x)[:2] for x in metricsByYear['LOCATION']]
metricsByYear = metricsByYear.drop(columns='LOCATION')
metricsByYear.sort_values(by='YEAR', ascending=True)
metricsByYear
# Out:
#       YEAR                           BRANCH  CIRCULATION  COMPUTER_SESSIONS  \
# 0     2011                      Albany Park     120059.0            21966.0
# 681   2011                      Oriole Park     139626.0            17721.0
# 232   2011                         Clearing      77943.0            20401.0
# 694   2011                   Portage-Cragin     118133.0            24273.0
# 707   2011                          Pullman      25807.0            22283.0
# ...    ...                              ...          ...                ...
# 283   2023  Daley, Richard M. - W. Humboldt       4815.0             3878.0
# 615   2023                            Merlo      36653.0             4108.0
# 50    2023                           Austin       2959.0             3187.0
# 295   2023                         Douglass       1266.0             2639.0
# 1011  2023                      Water Works      11988.0              648.0
#
#       VISITORS   LATITUDE  LONGITUDE
# 0     117425.0  41.975579 -87.713613
# 681   139799.0  41.978098 -87.814200
# 232   109231.0  41.776653 -87.782188
# 694   112283.0  41.938836 -87.754671
# 707    80816.0  41.694365 -87.618141
# ...        ...        ...        ...
# 283    17469.0  41.894727 -87.706384
# 615    46193.0  41.940132 -87.646029
# 50     14753.0  41.889173 -87.765820
# 295     6104.0  41.864412 -87.710175
# 1011   15985.0  41.897484 -87.623378
#
# [1012 rows x 7 columns]

# %%
#df is the dataframe you would use, latitude is the latitude metric, longitude is the longitude metric, branch is the library branch name column,
#timelapse is the duration over which you want to observe your data, maptitle is the title you want for your map.
def scatterMapBoxOverTime(df,latitude,longitude,branch,metric,timelapse,maptitle):
    fig = px.scatter_mapbox(df, lat=latitude, lon=longitude, color=branch,size=metric, 
                            color_continuous_scale=["black", "purple", "red" ],
                            animation_frame= timelapse, size_max=30, height = 600,
                            width = 1000, title= maptitle, mapbox_style="open-street-map")
    return fig


figureExample = scatterMapBoxOverTime(metricsByYear,'LATITUDE','LONGITUDE','BRANCH','COMPUTER_SESSIONS','YEAR','Sum of Computer Sessions by Year for all Branches')
figureExample.show()

# %% [markdown]
# Things to Try:
# - Visitors/Time (month to month, year to year)
# - Computer Sessions per Visitor over time
