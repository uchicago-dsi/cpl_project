# %% [markdown]
# ## Importing Packages ##

# %%
# Import packages from Python standard library
import numpy as np
import pandas as pd
import re
from pathlib import Path
import seaborn as sns
import matplotlib.pyplot as plt
from shapely import wkt
import geopandas as gpd
import geodatasets
import ast
import folium

# %% [markdown]
# ## Loading Datasets & Cleaning ##

# %%
#Reading in clean Internet Demographics dataset 
clean_internet_demographics = pd.read_csv('../../data/clean/internet_demographics.csv')
clean_internet_demographics.head(2)
# Out:
#          geoid                              qualifying name  \
# 0  17031823303  Census Tract 8233.03, Cook County, Illinois
# 1  17031823304  Census Tract 8233.04, Cook County, Illinois
#
#    current land area (sq. m)  current water area (sq. m)  \
# 0                    2008920                           0
# 1                    3553267                           0
#
#    Total Surveyed Computer Ownership  \
# 0                               1617
# 1                               2634
#
#    Std. Error: Total Surveyed Computer Ownership  total: has a computer  \
# 0                                       113.9394                   1476
# 1                                       176.9697                   2075
#
#    std. error: total: has a computer  total: no computer  \
# 0                           125.4545                 141
# 1                           133.9394                 559
#
#    std. error: total: no computer  ...  \
# 0                        54.54546  ...
# 1                       134.54550  ...
#
#    std. error: total:  satellite internet service  \
# 0                                        23.63636
# 1                                        59.39394
#
#    total:  satellite internet service satellite internet service with no other type of internet subscription  \
# 0                                                  0
# 1                                                 10
#
#    std. error: total:  satellite internet service satellite internet service with no other type of internet subscription  \
# 0                                           7.272727
# 1                                           7.272727
#
#    total:  other service with no other type of internet subscription  \
# 0                                                  0
# 1                                                  0
#
#    std. error: total:  other service with no other type of internet subscription  \
# 0                                           7.272727
# 1                                          10.303030
#
#    total: internet access without a subscription  \
# 0                                            129
# 1                                            117
#
#    std. error: total: internet access without a subscription  \
# 0                                           61.21212
# 1                                           62.42424
#
#    total: no internet access  std. error: total: no internet access  \
# 0                        184                               57.57576
# 1                        634                              127.27270
#
#                                             geometry
# 0  POLYGON ((-87.720963 41.683952, -87.720304 41....
# 1  MULTIPOLYGON (((-87.72003618903081 41.68396731...
#
# [2 rows x 37 columns]

# %% [markdown]
# **The way in which the raw data file was compiled into the clean data file makes it confusing to understand the census data (numbers don't seem to add up correctly), so I am going to read in the raw data and only pull out the 'total' columns.**

# %%
#Reading in raw Internet Demographics Census Dataset
full_raw_internet_demographics = pd.read_csv('../../data/raw/demographics/R13395758_SL140.csv')
raw_internet_demographics = full_raw_internet_demographics[['FIPS','Qualifying Name',
'Total: With An Internet Subscription',
'Total: With An Internet Subscription Dial-Up With No Other Type Of Internet Subscription',
'Total: With An Internet Subscription Broadband Of Any Type',
'Total: With An Internet Subscription Cellular Data Plan',
'Total: With An Internet Subscription Cellular Data Plan Cellular Data Plan With No Other Type Of Internet Subscription',
'Total:  Broadband Such As Cable Fiber Optic Or Dsl',
'Total:  Broadband Such As Cable Fiber Optic Or Dsl Broadband Such As Cable Fiber Optic Or Dsl With No Other Type Of Internet Subscription',
'Total:  Satellite Internet Service',
'Total:  Satellite Internet Service Satellite Internet Service With No Other Type Of Internet Subscription',
'Total:  Other Service With No Other Type Of Internet Subscription',
'Total: Internet Access Without A Subscription',
'Total: No Internet Access',
'Total: Has A Computer',
'Total: Has A Computer: With Dial-Up Internet Subscription Alone',
'Total: Has A Computer: With A Broadband Internet Subscription',
'Total: Has A Computer: Without An Internet Subscription',
'Total: No Computer',
'Total',
'Total: With An Internet Subscription Dial-Up Alone',
'Total: With An Internet Subscription Broadband Such As Cable Fiber Optic Or Dsl',
'Total: With An Internet Subscription Satellite Internet Service',
'Total: With An Internet Subscription Other Service',]]

raw_internet_demographics.head(3)
# Out:
#           FIPS                             Qualifying Name  \
# 0     Geo_FIPS                                   Geo_QName
# 1  17031010100     Census Tract 101, Cook County, Illinois
# 2  17031010201  Census Tract 102.01, Cook County, Illinois
#
#   Total: With An Internet Subscription  \
# 0                  ACS21_5yr_B28002002
# 1                                 1952
# 2                                 2543
#
#   Total: With An Internet Subscription Dial-Up With No Other Type Of Internet Subscription  \
# 0                                ACS21_5yr_B28002003
# 1                                                 17
# 2                                                  0
#
#   Total: With An Internet Subscription Broadband Of Any Type  \
# 0                                ACS21_5yr_B28002004
# 1                                               1935
# 2                                               2543
#
#   Total: With An Internet Subscription Cellular Data Plan  \
# 0                                ACS21_5yr_B28002005
# 1                                               1761
# 2                                               2231
#
#   Total: With An Internet Subscription Cellular Data Plan Cellular Data Plan With No Other Type Of Internet Subscription  \
# 0                                ACS21_5yr_B28002006
# 1                                                225
# 2                                                266
#
#   Total:  Broadband Such As Cable Fiber Optic Or Dsl  \
# 0                                ACS21_5yr_B28002007
# 1                                               1710
# 2                                               2234
#
#   Total:  Broadband Such As Cable Fiber Optic Or Dsl Broadband Such As Cable Fiber Optic Or Dsl With No Other Type Of Internet Subscription  \
# 0                                ACS21_5yr_B28002008
# 1                                                174
# 2                                                312
#
#   Total:  Satellite Internet Service  ... Total: Has A Computer  \
# 0                ACS21_5yr_B28002009  ...   ACS21_5yr_B28003002
# 1                                 62  ...                  2112
# 2                                128  ...                  2726
#
#   Total: Has A Computer: With Dial-Up Internet Subscription Alone  \
# 0                                ACS21_5yr_B28003003
# 1                                                 17
# 2                                                  0
#
#   Total: Has A Computer: With A Broadband Internet Subscription  \
# 0                                ACS21_5yr_B28003004
# 1                                               1870
# 2                                               2468
#
#   Total: Has A Computer: Without An Internet Subscription  \
# 0                                ACS21_5yr_B28003005
# 1                                                225
# 2                                                258
#
#     Total: No Computer                Total  \
# 0  ACS21_5yr_B28003006  ACS21_5yr_B28002001
# 1                  299                 2411
# 2                  270                 2996
#
#   Total: With An Internet Subscription Dial-Up Alone  \
# 0                                ACS21_5yr_B28011003
# 1                                                 17
# 2                                                  0
#
#   Total: With An Internet Subscription Broadband Such As Cable Fiber Optic Or Dsl  \
# 0                                ACS21_5yr_B28011004
# 1                                               1710
# 2                                               2234
#
#   Total: With An Internet Subscription Satellite Internet Service  \
# 0                                ACS21_5yr_B28011005
# 1                                                 62
# 2                                                128
#
#   Total: With An Internet Subscription Other Service
# 0                                ACS21_5yr_B28011006
# 1                                                  0
# 2                                                 31
#
# [3 rows x 24 columns]

# %% [markdown]
# In the raw_internet_demographics dataset that I made, it does not include the 'geometry' column that is in the clean_internet_demographics dataset. So, I need to merge the 'geometry' column into the raw_internet_demographics. So, I must first rename the 'Qualifying Name' column to 'qualifying name' so that the merge will work. I am also going to change the column name 'FIPS' to 'geoid', because the clean_internet_demographics dataset calls it 'geiod'.

# %%
#Renaming 'Qualifying Name' to 'qualifying name' so that I can merge the geometry column into the raw_internet_demographics from clean_internet_demographics
raw_internet_demographics_rename = raw_internet_demographics.rename(columns={'Qualifying Name': 'qualifying name','FIPS':'geoid'})

#Dropping first row that contains unnecessary descriptions
raw_internet_demographics_drop = raw_internet_demographics_rename.drop(labels=0,axis=0)
raw_internet_demographics_drop.head(2)
# Out:
#          geoid                             qualifying name  \
# 1  17031010100     Census Tract 101, Cook County, Illinois
# 2  17031010201  Census Tract 102.01, Cook County, Illinois
#
#   Total: With An Internet Subscription  \
# 1                                 1952
# 2                                 2543
#
#   Total: With An Internet Subscription Dial-Up With No Other Type Of Internet Subscription  \
# 1                                                 17
# 2                                                  0
#
#   Total: With An Internet Subscription Broadband Of Any Type  \
# 1                                               1935
# 2                                               2543
#
#   Total: With An Internet Subscription Cellular Data Plan  \
# 1                                               1761
# 2                                               2231
#
#   Total: With An Internet Subscription Cellular Data Plan Cellular Data Plan With No Other Type Of Internet Subscription  \
# 1                                                225
# 2                                                266
#
#   Total:  Broadband Such As Cable Fiber Optic Or Dsl  \
# 1                                               1710
# 2                                               2234
#
#   Total:  Broadband Such As Cable Fiber Optic Or Dsl Broadband Such As Cable Fiber Optic Or Dsl With No Other Type Of Internet Subscription  \
# 1                                                174
# 2                                                312
#
#   Total:  Satellite Internet Service  ... Total: Has A Computer  \
# 1                                 62  ...                  2112
# 2                                128  ...                  2726
#
#   Total: Has A Computer: With Dial-Up Internet Subscription Alone  \
# 1                                                 17
# 2                                                  0
#
#   Total: Has A Computer: With A Broadband Internet Subscription  \
# 1                                               1870
# 2                                               2468
#
#   Total: Has A Computer: Without An Internet Subscription Total: No Computer  \
# 1                                                225                     299
# 2                                                258                     270
#
#   Total Total: With An Internet Subscription Dial-Up Alone  \
# 1  2411                                                 17
# 2  2996                                                  0
#
#   Total: With An Internet Subscription Broadband Such As Cable Fiber Optic Or Dsl  \
# 1                                               1710
# 2                                               2234
#
#   Total: With An Internet Subscription Satellite Internet Service  \
# 1                                                 62
# 2                                                128
#
#   Total: With An Internet Subscription Other Service
# 1                                                  0
# 2                                                 31
#
# [2 rows x 24 columns]

# %%
#Merging: to ensure that the geometry matches the correct census tracts, I merge using the 'qualifying name' column
to_merge = clean_internet_demographics[['qualifying name','geometry']]
to_merge.head()
# Out:
#                                qualifying name  \
# 0  Census Tract 8233.03, Cook County, Illinois
# 1  Census Tract 8233.04, Cook County, Illinois
# 2     Census Tract 7404, Cook County, Illinois
# 3     Census Tract 7403, Cook County, Illinois
# 4  Census Tract 8228.02, Cook County, Illinois
#
#                                             geometry
# 0  POLYGON ((-87.720963 41.683952, -87.720304 41....
# 1  MULTIPOLYGON (((-87.72003618903081 41.68396731...
# 2  POLYGON ((-87.72008 41.691274, -87.719372 41.6...
# 3  POLYGON ((-87.720431 41.698569, -87.720066 41....
# 4  MULTIPOLYGON (((-87.720752 41.702042, -87.7207...

# %%
#Merging the geometry column into the raw_internet_demographics_rename and renaming it
raw_internet_demo = raw_internet_demographics_drop.merge(to_merge, on='qualifying name')
raw_internet_demo.head(2)
# Out:
#          geoid                             qualifying name  \
# 0  17031010100     Census Tract 101, Cook County, Illinois
# 1  17031010201  Census Tract 102.01, Cook County, Illinois
#
#   Total: With An Internet Subscription  \
# 0                                 1952
# 1                                 2543
#
#   Total: With An Internet Subscription Dial-Up With No Other Type Of Internet Subscription  \
# 0                                                 17
# 1                                                  0
#
#   Total: With An Internet Subscription Broadband Of Any Type  \
# 0                                               1935
# 1                                               2543
#
#   Total: With An Internet Subscription Cellular Data Plan  \
# 0                                               1761
# 1                                               2231
#
#   Total: With An Internet Subscription Cellular Data Plan Cellular Data Plan With No Other Type Of Internet Subscription  \
# 0                                                225
# 1                                                266
#
#   Total:  Broadband Such As Cable Fiber Optic Or Dsl  \
# 0                                               1710
# 1                                               2234
#
#   Total:  Broadband Such As Cable Fiber Optic Or Dsl Broadband Such As Cable Fiber Optic Or Dsl With No Other Type Of Internet Subscription  \
# 0                                                174
# 1                                                312
#
#   Total:  Satellite Internet Service  ...  \
# 0                                 62  ...
# 1                                128  ...
#
#   Total: Has A Computer: With Dial-Up Internet Subscription Alone  \
# 0                                                 17
# 1                                                  0
#
#   Total: Has A Computer: With A Broadband Internet Subscription  \
# 0                                               1870
# 1                                               2468
#
#   Total: Has A Computer: Without An Internet Subscription Total: No Computer  \
# 0                                                225                     299
# 1                                                258                     270
#
#   Total Total: With An Internet Subscription Dial-Up Alone  \
# 0  2411                                                 17
# 1  2996                                                  0
#
#   Total: With An Internet Subscription Broadband Such As Cable Fiber Optic Or Dsl  \
# 0                                               1710
# 1                                               2234
#
#   Total: With An Internet Subscription Satellite Internet Service  \
# 0                                                 62
# 1                                                128
#
#   Total: With An Internet Subscription Other Service  \
# 0                                                  0
# 1                                                 31
#
#                                             geometry
# 0  POLYGON ((-87.676277 42.022965, -87.675968 42....
# 1  POLYGON ((-87.684317 42.019481, -87.683901 42....
#
# [2 rows x 25 columns]

# %% [markdown]
# When trying to take a percentage (dividing one column over another), Python does not see it as division for each numerical value. So, I have to convert the list of numbers in every column to be considered integers that can be divided.

# %%
#Convert list of numbers to integers
for i in range(2,23):
    
    raw_internet_demo.iloc[:, i] = pd.to_numeric(raw_internet_demo.iloc[:, i])

raw_internet_demo.head(2)
# Out:
#          geoid                             qualifying name  \
# 0  17031010100     Census Tract 101, Cook County, Illinois
# 1  17031010201  Census Tract 102.01, Cook County, Illinois
#
#   Total: With An Internet Subscription  \
# 0                                 1952
# 1                                 2543
#
#   Total: With An Internet Subscription Dial-Up With No Other Type Of Internet Subscription  \
# 0                                                 17
# 1                                                  0
#
#   Total: With An Internet Subscription Broadband Of Any Type  \
# 0                                               1935
# 1                                               2543
#
#   Total: With An Internet Subscription Cellular Data Plan  \
# 0                                               1761
# 1                                               2231
#
#   Total: With An Internet Subscription Cellular Data Plan Cellular Data Plan With No Other Type Of Internet Subscription  \
# 0                                                225
# 1                                                266
#
#   Total:  Broadband Such As Cable Fiber Optic Or Dsl  \
# 0                                               1710
# 1                                               2234
#
#   Total:  Broadband Such As Cable Fiber Optic Or Dsl Broadband Such As Cable Fiber Optic Or Dsl With No Other Type Of Internet Subscription  \
# 0                                                174
# 1                                                312
#
#   Total:  Satellite Internet Service  ...  \
# 0                                 62  ...
# 1                                128  ...
#
#   Total: Has A Computer: With Dial-Up Internet Subscription Alone  \
# 0                                                 17
# 1                                                  0
#
#   Total: Has A Computer: With A Broadband Internet Subscription  \
# 0                                               1870
# 1                                               2468
#
#   Total: Has A Computer: Without An Internet Subscription Total: No Computer  \
# 0                                                225                     299
# 1                                                258                     270
#
#   Total Total: With An Internet Subscription Dial-Up Alone  \
# 0  2411                                                 17
# 1  2996                                                  0
#
#   Total: With An Internet Subscription Broadband Such As Cable Fiber Optic Or Dsl  \
# 0                                               1710
# 1                                               2234
#
#   Total: With An Internet Subscription Satellite Internet Service  \
# 0                                                 62
# 1                                                128
#
#   Total: With An Internet Subscription Other Service  \
# 0                                                  0
# 1                                                 31
#
#                                             geometry
# 0  POLYGON ((-87.676277 42.022965, -87.675968 42....
# 1  POLYGON ((-87.684317 42.019481, -87.683901 42....
#
# [2 rows x 25 columns]

# %%
raw_internet_demo['Total: Has A Computer: Without An Internet Subscription'].dtype
# Out:
# dtype('O')

# %%
#Removing census tracts that have 0's across all columns and replacing them with NaN so that percentages can still be calculated without = 0
raw_internet_demos_all = raw_internet_demo.replace(0, np.nan)
raw_internet_demos_all.head(2)
# Out:
#          geoid                             qualifying name  \
# 0  17031010100     Census Tract 101, Cook County, Illinois
# 1  17031010201  Census Tract 102.01, Cook County, Illinois
#
#    Total: With An Internet Subscription  \
# 0                                1952.0
# 1                                2543.0
#
#    Total: With An Internet Subscription Dial-Up With No Other Type Of Internet Subscription  \
# 0                                               17.0
# 1                                                NaN
#
#    Total: With An Internet Subscription Broadband Of Any Type  \
# 0                                             1935.0
# 1                                             2543.0
#
#    Total: With An Internet Subscription Cellular Data Plan  \
# 0                                             1761.0
# 1                                             2231.0
#
#    Total: With An Internet Subscription Cellular Data Plan Cellular Data Plan With No Other Type Of Internet Subscription  \
# 0                                              225.0
# 1                                              266.0
#
#    Total:  Broadband Such As Cable Fiber Optic Or Dsl  \
# 0                                             1710.0
# 1                                             2234.0
#
#    Total:  Broadband Such As Cable Fiber Optic Or Dsl Broadband Such As Cable Fiber Optic Or Dsl With No Other Type Of Internet Subscription  \
# 0                                              174.0
# 1                                              312.0
#
#    Total:  Satellite Internet Service  ...  \
# 0                                62.0  ...
# 1                               128.0  ...
#
#    Total: Has A Computer: With Dial-Up Internet Subscription Alone  \
# 0                                               17.0
# 1                                                NaN
#
#    Total: Has A Computer: With A Broadband Internet Subscription  \
# 0                                             1870.0
# 1                                             2468.0
#
#    Total: Has A Computer: Without An Internet Subscription  \
# 0                                              225.0
# 1                                              258.0
#
#    Total: No Computer   Total  \
# 0               299.0  2411.0
# 1               270.0  2996.0
#
#    Total: With An Internet Subscription Dial-Up Alone  \
# 0                                               17.0
# 1                                                NaN
#
#    Total: With An Internet Subscription Broadband Such As Cable Fiber Optic Or Dsl  \
# 0                                             1710.0
# 1                                             2234.0
#
#    Total: With An Internet Subscription Satellite Internet Service  \
# 0                                               62.0
# 1                                              128.0
#
#    Total: With An Internet Subscription Other Service  \
# 0                                                  0
# 1                                                 31
#
#                                             geometry
# 0  POLYGON ((-87.676277 42.022965, -87.675968 42....
# 1  POLYGON ((-87.684317 42.019481, -87.683901 42....
#
# [2 rows x 25 columns]

# %% [markdown]
# ## Heatmaps ##

# %% [markdown]
# ### Percent of People with and without Internet Access ###

# %%
#Adding Column that calculates (Total) - (No Internet Access)/(Total)
raw_internet_demos_all['Percent of People with Internet Access'] = ((raw_internet_demos_all['Total'] - (raw_internet_demos_all['Total: No Internet Access']))/ (raw_internet_demos_all['Total']))
raw_internet_demos_all.head(2)
# Out:
#          geoid                             qualifying name  \
# 0  17031010100     Census Tract 101, Cook County, Illinois
# 1  17031010201  Census Tract 102.01, Cook County, Illinois
#
#    Total: With An Internet Subscription  \
# 0                                1952.0
# 1                                2543.0
#
#    Total: With An Internet Subscription Dial-Up With No Other Type Of Internet Subscription  \
# 0                                               17.0
# 1                                                NaN
#
#    Total: With An Internet Subscription Broadband Of Any Type  \
# 0                                             1935.0
# 1                                             2543.0
#
#    Total: With An Internet Subscription Cellular Data Plan  \
# 0                                             1761.0
# 1                                             2231.0
#
#    Total: With An Internet Subscription Cellular Data Plan Cellular Data Plan With No Other Type Of Internet Subscription  \
# 0                                              225.0
# 1                                              266.0
#
#    Total:  Broadband Such As Cable Fiber Optic Or Dsl  \
# 0                                             1710.0
# 1                                             2234.0
#
#    Total:  Broadband Such As Cable Fiber Optic Or Dsl Broadband Such As Cable Fiber Optic Or Dsl With No Other Type Of Internet Subscription  \
# 0                                              174.0
# 1                                              312.0
#
#    Total:  Satellite Internet Service  ...  \
# 0                                62.0  ...
# 1                               128.0  ...
#
#    Total: Has A Computer: With A Broadband Internet Subscription  \
# 0                                             1870.0
# 1                                             2468.0
#
#    Total: Has A Computer: Without An Internet Subscription  \
# 0                                              225.0
# 1                                              258.0
#
#    Total: No Computer   Total  \
# 0               299.0  2411.0
# 1               270.0  2996.0
#
#    Total: With An Internet Subscription Dial-Up Alone  \
# 0                                               17.0
# 1                                                NaN
#
#    Total: With An Internet Subscription Broadband Such As Cable Fiber Optic Or Dsl  \
# 0                                             1710.0
# 1                                             2234.0
#
#    Total: With An Internet Subscription Satellite Internet Service  \
# 0                                               62.0
# 1                                              128.0
#
#    Total: With An Internet Subscription Other Service  \
# 0                                                  0
# 1                                                 31
#
#                                             geometry  \
# 0  POLYGON ((-87.676277 42.022965, -87.675968 42....
# 1  POLYGON ((-87.684317 42.019481, -87.683901 42....
#
#    Percent of People with Internet Access
# 0                                0.846951
# 1                                0.903204
#
# [2 rows x 26 columns]

# %%
#Adding Column that calculates No Internet Acces/Total
raw_internet_demos_all['Percent of People without Internet Access'] = (raw_internet_demos_all['Total: No Internet Access'])/ (raw_internet_demos_all['Total'])
raw_internet_demos_all
# Out:
#            geoid                                qualifying name  \
# 0    17031010100        Census Tract 101, Cook County, Illinois
# 1    17031010201     Census Tract 102.01, Cook County, Illinois
# 2    17031010202     Census Tract 102.02, Cook County, Illinois
# 3    17031010300        Census Tract 103, Cook County, Illinois
# 4    17031010400        Census Tract 104, Cook County, Illinois
# ..           ...                                            ...
# 864  17031980100       Census Tract 9801, Cook County, Illinois
# 865  17031990000       Census Tract 9900, Cook County, Illinois
# 866  17043840000     Census Tract 8400, DuPage County, Illinois
# 867  17043840801  Census Tract 8408.01, DuPage County, Illinois
# 868  17043840802  Census Tract 8408.02, DuPage County, Illinois
#
#      Total: With An Internet Subscription  \
# 0                                  1952.0
# 1                                  2543.0
# 2                                  1040.0
# 3                                  2548.0
# 4                                  1487.0
# ..                                    ...
# 864                                   NaN
# 865                                   NaN
# 866                                 818.0
# 867                                 642.0
# 868                                1981.0
#
#      Total: With An Internet Subscription Dial-Up With No Other Type Of Internet Subscription  \
# 0                                                 17.0
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 864                                                NaN
# 865                                                NaN
# 866                                                6.0
# 867                                                NaN
# 868                                                NaN
#
#      Total: With An Internet Subscription Broadband Of Any Type  \
# 0                                               1935.0
# 1                                               2543.0
# 2                                               1040.0
# 3                                               2548.0
# 4                                               1487.0
# ..                                                 ...
# 864                                                NaN
# 865                                                NaN
# 866                                              812.0
# 867                                              642.0
# 868                                             1981.0
#
#      Total: With An Internet Subscription Cellular Data Plan  \
# 0                                               1761.0
# 1                                               2231.0
# 2                                                862.0
# 3                                               2320.0
# 4                                               1423.0
# ..                                                 ...
# 864                                                NaN
# 865                                                NaN
# 866                                              778.0
# 867                                              566.0
# 868                                             1926.0
#
#      Total: With An Internet Subscription Cellular Data Plan Cellular Data Plan With No Other Type Of Internet Subscription  \
# 0                                                225.0
# 1                                                266.0
# 2                                                151.0
# 3                                                352.0
# 4                                                216.0
# ..                                                 ...
# 864                                                NaN
# 865                                                NaN
# 866                                               81.0
# 867                                               47.0
# 868                                              283.0
#
#      Total:  Broadband Such As Cable Fiber Optic Or Dsl  \
# 0                                               1710.0
# 1                                               2234.0
# 2                                                852.0
# 3                                               2112.0
# 4                                               1238.0
# ..                                                 ...
# 864                                                NaN
# 865                                                NaN
# 866                                              681.0
# 867                                              575.0
# 868                                             1594.0
#
#      Total:  Broadband Such As Cable Fiber Optic Or Dsl Broadband Such As Cable Fiber Optic Or Dsl With No Other Type Of Internet Subscription  \
# 0                                                174.0
# 1                                                312.0
# 2                                                161.0
# 3                                                185.0
# 4                                                 64.0
# ..                                                 ...
# 864                                                NaN
# 865                                                NaN
# 866                                               16.0
# 867                                               71.0
# 868                                               55.0
#
#      Total:  Satellite Internet Service  ...  \
# 0                                  62.0  ...
# 1                                 128.0  ...
# 2                                  56.0  ...
# 3                                 183.0  ...
# 4                                  47.0  ...
# ..                                  ...  ...
# 864                                 NaN  ...
# 865                                 NaN  ...
# 866                               134.0  ...
# 867                                34.0  ...
# 868                               338.0  ...
#
#      Total: Has A Computer: Without An Internet Subscription  \
# 0                                                225.0
# 1                                                258.0
# 2                                                137.0
# 3                                                327.0
# 4                                                187.0
# ..                                                 ...
# 864                                                NaN
# 865                                                NaN
# 866                                               53.0
# 867                                               38.0
# 868                                               79.0
#
#      Total: No Computer   Total  \
# 0                 299.0  2411.0
# 1                 270.0  2996.0
# 2                  75.0  1234.0
# 3                 160.0  2995.0
# 4                 360.0  2034.0
# ..                  ...     ...
# 864                 NaN     NaN
# 865                 NaN     NaN
# 866                72.0   937.0
# 867               298.0   956.0
# 868               126.0  2159.0
#
#      Total: With An Internet Subscription Dial-Up Alone  \
# 0                                                 17.0
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 864                                                NaN
# 865                                                NaN
# 866                                                6.0
# 867                                                NaN
# 868                                                NaN
#
#      Total: With An Internet Subscription Broadband Such As Cable Fiber Optic Or Dsl  \
# 0                                               1710.0
# 1                                               2234.0
# 2                                                852.0
# 3                                               2112.0
# 4                                               1238.0
# ..                                                 ...
# 864                                                NaN
# 865                                                NaN
# 866                                              681.0
# 867                                              575.0
# 868                                             1594.0
#
#      Total: With An Internet Subscription Satellite Internet Service  \
# 0                                                 62.0
# 1                                                128.0
# 2                                                 56.0
# 3                                                183.0
# 4                                                 47.0
# ..                                                 ...
# 864                                                NaN
# 865                                                NaN
# 866                                              134.0
# 867                                               34.0
# 868                                              338.0
#
#      Total: With An Internet Subscription Other Service  \
# 0                                                    0
# 1                                                   31
# 2                                                    0
# 3                                                  100
# 4                                                    0
# ..                                                 ...
# 864                                                  0
# 865                                                  0
# 866                                                  0
# 867                                                  5
# 868                                                 67
#
#                                               geometry  \
# 0    POLYGON ((-87.676277 42.022965, -87.675968 42....
# 1    POLYGON ((-87.684317 42.019481, -87.683901 42....
# 2    POLYGON ((-87.676745 42.01941, -87.67651175102...
# 3    POLYGON ((-87.671212 42.019373, -87.670858 42....
# 4    POLYGON ((-87.663213 42.012834, -87.662494 42....
# ..                                                 ...
# 864  POLYGON ((-87.762058 41.792739, -87.761701 41....
# 865  MULTIPOLYGON (((-87.609113 41.888267, -87.6054...
# 866  POLYGON ((-87.938967 41.993515, -87.938927 41....
# 867  MULTIPOLYGON (((-87.939058 41.958485, -87.9390...
# 868  POLYGON ((-87.939284 41.960893, -87.939229 41....
#
#      Percent of People with Internet Access  \
# 0                                  0.846951
# 1                                  0.903204
# 2                                  0.890600
# 3                                  0.877462
# 4                                  0.779744
# ..                                      ...
# 864                                     NaN
# 865                                     NaN
# 866                                0.872999
# 867                                0.696653
# 868                                0.917554
#
#      Percent of People without Internet Access
# 0                                     0.153049
# 1                                     0.096796
# 2                                     0.109400
# 3                                     0.122538
# 4                                     0.220256
# ..                                         ...
# 864                                        NaN
# 865                                        NaN
# 866                                   0.127001
# 867                                   0.303347
# 868                                   0.082446
#
# [869 rows x 27 columns]

# %%
#Reading in clean branch data
branchLocsOnly = pd.read_csv('../../data/clean/branches.csv')

# this line makes a copy of the raw_internet_demos_all data frame so we can manipulate without affecting our primary dataset
internet_access_percentage = raw_internet_demos_all.copy(deep = True)

# the following converts the data frame to a geo data frame and plots Percentage of People with Internet Access
internet_access_percentage = gpd.GeoDataFrame(
    internet_access_percentage.loc[:, [c for c in internet_access_percentage.columns if c != "geometry"]],
    geometry=gpd.GeoSeries.from_wkt(internet_access_percentage["geometry"]),
    crs="epsg:4326",
    )

fig, ax = plt.subplots(1, figsize=(6, 6))
base = internet_access_percentage.plot(column='Percent of People with Internet Access', legend=True, ax=ax, cmap='inferno')
ax.axis('off')
ax.set_title('Percent of People with Internet Access per Census Tract', fontdict={'fontsize': '12', 'fontweight' : '3'})

#Adding small white dots to represent library branch points
branchLocsOnly.crs = 'EPSG:4326'
branchLocsOnly[['Latitude', 'Longitude']] = [ast.literal_eval(x)[:2] for x in branchLocsOnly['LOCATION']]
branchLocsOnly = branchLocsOnly.drop(columns='LOCATION')


branchLocsOnly = gpd.GeoDataFrame(
    branchLocsOnly, geometry=gpd.points_from_xy(branchLocsOnly.Longitude, branchLocsOnly.Latitude), crs="EPSG:4326")


branchLocsOnly.plot(ax=base, marker='o', color='white', markersize=5);

# %% [markdown]
# ### Percent of People with and without Computers ###

# %%
#Adding Column that calculates: (Total) - (No Computer)/(Total) = Percentage of People with Computers
raw_internet_demos_all['Percent of People with Computers'] = ((raw_internet_demos_all['Total'] - (raw_internet_demos_all['Total: No Computer']))/ (raw_internet_demos_all['Total']))
raw_internet_demos_all.head(2)
# Out:
#          geoid                             qualifying name  \
# 0  17031010100     Census Tract 101, Cook County, Illinois
# 1  17031010201  Census Tract 102.01, Cook County, Illinois
#
#    Total: With An Internet Subscription  \
# 0                                1952.0
# 1                                2543.0
#
#    Total: With An Internet Subscription Dial-Up With No Other Type Of Internet Subscription  \
# 0                                               17.0
# 1                                                NaN
#
#    Total: With An Internet Subscription Broadband Of Any Type  \
# 0                                             1935.0
# 1                                             2543.0
#
#    Total: With An Internet Subscription Cellular Data Plan  \
# 0                                             1761.0
# 1                                             2231.0
#
#    Total: With An Internet Subscription Cellular Data Plan Cellular Data Plan With No Other Type Of Internet Subscription  \
# 0                                              225.0
# 1                                              266.0
#
#    Total:  Broadband Such As Cable Fiber Optic Or Dsl  \
# 0                                             1710.0
# 1                                             2234.0
#
#    Total:  Broadband Such As Cable Fiber Optic Or Dsl Broadband Such As Cable Fiber Optic Or Dsl With No Other Type Of Internet Subscription  \
# 0                                              174.0
# 1                                              312.0
#
#    Total:  Satellite Internet Service  ...  Total: No Computer   Total  \
# 0                                62.0  ...               299.0  2411.0
# 1                               128.0  ...               270.0  2996.0
#
#    Total: With An Internet Subscription Dial-Up Alone  \
# 0                                               17.0
# 1                                                NaN
#
#    Total: With An Internet Subscription Broadband Such As Cable Fiber Optic Or Dsl  \
# 0                                             1710.0
# 1                                             2234.0
#
#    Total: With An Internet Subscription Satellite Internet Service  \
# 0                                               62.0
# 1                                              128.0
#
#    Total: With An Internet Subscription Other Service  \
# 0                                                  0
# 1                                                 31
#
#                                             geometry  \
# 0  POLYGON ((-87.676277 42.022965, -87.675968 42....
# 1  POLYGON ((-87.684317 42.019481, -87.683901 42....
#
#    Percent of People with Internet Access  \
# 0                                0.846951
# 1                                0.903204
#
#    Percent of People without Internet Access  Percent of People with Computers
# 0                                   0.153049                          0.875985
# 1                                   0.096796                          0.909880
#
# [2 rows x 28 columns]

# %%
#Adding Column that calculates: No computer/Total = Percent of people without computers
raw_internet_demos_all['Percent of People without Computers'] = (raw_internet_demos_all['Total: No Computer'])/ (raw_internet_demos_all['Total'])
raw_internet_demos_all
# Out:
#            geoid                                qualifying name  \
# 0    17031010100        Census Tract 101, Cook County, Illinois
# 1    17031010201     Census Tract 102.01, Cook County, Illinois
# 2    17031010202     Census Tract 102.02, Cook County, Illinois
# 3    17031010300        Census Tract 103, Cook County, Illinois
# 4    17031010400        Census Tract 104, Cook County, Illinois
# ..           ...                                            ...
# 864  17031980100       Census Tract 9801, Cook County, Illinois
# 865  17031990000       Census Tract 9900, Cook County, Illinois
# 866  17043840000     Census Tract 8400, DuPage County, Illinois
# 867  17043840801  Census Tract 8408.01, DuPage County, Illinois
# 868  17043840802  Census Tract 8408.02, DuPage County, Illinois
#
#      Total: With An Internet Subscription  \
# 0                                  1952.0
# 1                                  2543.0
# 2                                  1040.0
# 3                                  2548.0
# 4                                  1487.0
# ..                                    ...
# 864                                   NaN
# 865                                   NaN
# 866                                 818.0
# 867                                 642.0
# 868                                1981.0
#
#      Total: With An Internet Subscription Dial-Up With No Other Type Of Internet Subscription  \
# 0                                                 17.0
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 864                                                NaN
# 865                                                NaN
# 866                                                6.0
# 867                                                NaN
# 868                                                NaN
#
#      Total: With An Internet Subscription Broadband Of Any Type  \
# 0                                               1935.0
# 1                                               2543.0
# 2                                               1040.0
# 3                                               2548.0
# 4                                               1487.0
# ..                                                 ...
# 864                                                NaN
# 865                                                NaN
# 866                                              812.0
# 867                                              642.0
# 868                                             1981.0
#
#      Total: With An Internet Subscription Cellular Data Plan  \
# 0                                               1761.0
# 1                                               2231.0
# 2                                                862.0
# 3                                               2320.0
# 4                                               1423.0
# ..                                                 ...
# 864                                                NaN
# 865                                                NaN
# 866                                              778.0
# 867                                              566.0
# 868                                             1926.0
#
#      Total: With An Internet Subscription Cellular Data Plan Cellular Data Plan With No Other Type Of Internet Subscription  \
# 0                                                225.0
# 1                                                266.0
# 2                                                151.0
# 3                                                352.0
# 4                                                216.0
# ..                                                 ...
# 864                                                NaN
# 865                                                NaN
# 866                                               81.0
# 867                                               47.0
# 868                                              283.0
#
#      Total:  Broadband Such As Cable Fiber Optic Or Dsl  \
# 0                                               1710.0
# 1                                               2234.0
# 2                                                852.0
# 3                                               2112.0
# 4                                               1238.0
# ..                                                 ...
# 864                                                NaN
# 865                                                NaN
# 866                                              681.0
# 867                                              575.0
# 868                                             1594.0
#
#      Total:  Broadband Such As Cable Fiber Optic Or Dsl Broadband Such As Cable Fiber Optic Or Dsl With No Other Type Of Internet Subscription  \
# 0                                                174.0
# 1                                                312.0
# 2                                                161.0
# 3                                                185.0
# 4                                                 64.0
# ..                                                 ...
# 864                                                NaN
# 865                                                NaN
# 866                                               16.0
# 867                                               71.0
# 868                                               55.0
#
#      Total:  Satellite Internet Service  ...   Total  \
# 0                                  62.0  ...  2411.0
# 1                                 128.0  ...  2996.0
# 2                                  56.0  ...  1234.0
# 3                                 183.0  ...  2995.0
# 4                                  47.0  ...  2034.0
# ..                                  ...  ...     ...
# 864                                 NaN  ...     NaN
# 865                                 NaN  ...     NaN
# 866                               134.0  ...   937.0
# 867                                34.0  ...   956.0
# 868                               338.0  ...  2159.0
#
#      Total: With An Internet Subscription Dial-Up Alone  \
# 0                                                 17.0
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 864                                                NaN
# 865                                                NaN
# 866                                                6.0
# 867                                                NaN
# 868                                                NaN
#
#      Total: With An Internet Subscription Broadband Such As Cable Fiber Optic Or Dsl  \
# 0                                               1710.0
# 1                                               2234.0
# 2                                                852.0
# 3                                               2112.0
# 4                                               1238.0
# ..                                                 ...
# 864                                                NaN
# 865                                                NaN
# 866                                              681.0
# 867                                              575.0
# 868                                             1594.0
#
#      Total: With An Internet Subscription Satellite Internet Service  \
# 0                                                 62.0
# 1                                                128.0
# 2                                                 56.0
# 3                                                183.0
# 4                                                 47.0
# ..                                                 ...
# 864                                                NaN
# 865                                                NaN
# 866                                              134.0
# 867                                               34.0
# 868                                              338.0
#
#      Total: With An Internet Subscription Other Service  \
# 0                                                    0
# 1                                                   31
# 2                                                    0
# 3                                                  100
# 4                                                    0
# ..                                                 ...
# 864                                                  0
# 865                                                  0
# 866                                                  0
# 867                                                  5
# 868                                                 67
#
#                                               geometry  \
# 0    POLYGON ((-87.676277 42.022965, -87.675968 42....
# 1    POLYGON ((-87.684317 42.019481, -87.683901 42....
# 2    POLYGON ((-87.676745 42.01941, -87.67651175102...
# 3    POLYGON ((-87.671212 42.019373, -87.670858 42....
# 4    POLYGON ((-87.663213 42.012834, -87.662494 42....
# ..                                                 ...
# 864  POLYGON ((-87.762058 41.792739, -87.761701 41....
# 865  MULTIPOLYGON (((-87.609113 41.888267, -87.6054...
# 866  POLYGON ((-87.938967 41.993515, -87.938927 41....
# 867  MULTIPOLYGON (((-87.939058 41.958485, -87.9390...
# 868  POLYGON ((-87.939284 41.960893, -87.939229 41....
#
#      Percent of People with Internet Access  \
# 0                                  0.846951
# 1                                  0.903204
# 2                                  0.890600
# 3                                  0.877462
# 4                                  0.779744
# ..                                      ...
# 864                                     NaN
# 865                                     NaN
# 866                                0.872999
# 867                                0.696653
# 868                                0.917554
#
#      Percent of People without Internet Access  \
# 0                                     0.153049
# 1                                     0.096796
# 2                                     0.109400
# 3                                     0.122538
# 4                                     0.220256
# ..                                         ...
# 864                                        NaN
# 865                                        NaN
# 866                                   0.127001
# 867                                   0.303347
# 868                                   0.082446
#
#      Percent of People with Computers  Percent of People without Computers
# 0                            0.875985                             0.124015
# 1                            0.909880                             0.090120
# 2                            0.939222                             0.060778
# 3                            0.946578                             0.053422
# 4                            0.823009                             0.176991
# ..                                ...                                  ...
# 864                               NaN                                  NaN
# 865                               NaN                                  NaN
# 866                          0.923159                             0.076841
# 867                          0.688285                             0.311715
# 868                          0.941640                             0.058360
#
# [869 rows x 29 columns]

# %%
#Reading in clean branch data
branchLocsOnly = pd.read_csv('../../data/clean/branches.csv')

# this line makes a copy of the raw_internet_demos_all data frame so we can manipulate without affecting our primary dataset
computer_own_percentage = raw_internet_demos_all.copy(deep = True)

# the following converts the data frame to a geo data frame and plots Percentage of People with Computers
computer_own_percentage = gpd.GeoDataFrame(
    computer_own_percentage.loc[:, [c for c in computer_own_percentage.columns if c != "geometry"]],
    geometry=gpd.GeoSeries.from_wkt(computer_own_percentage["geometry"]),
    crs="epsg:4326",
    )

fig, ax = plt.subplots(1, figsize=(6, 6))
computer_own_percentage.plot(column='Percent of People with Computers', legend=True, ax=ax)
ax.axis('off')
ax.set_title('Percent of People with Computers', fontdict={'fontsize': '12', 'fontweight' : '3'})

#Adding small white dots to represent library branch points
branchLocsOnly.crs = 'EPSG:4326'
branchLocsOnly[['Latitude', 'Longitude']] = [ast.literal_eval(x)[:2] for x in branchLocsOnly['LOCATION']]
branchLocsOnly = branchLocsOnly.drop(columns='LOCATION')


branchLocsOnly = gpd.GeoDataFrame(
    branchLocsOnly, geometry=gpd.points_from_xy(branchLocsOnly.Longitude, branchLocsOnly.Latitude), crs="EPSG:4326")
#print(branchLocsOnly.head())


branchLocsOnly.plot(ax=base, marker='o', color='white', markersize=5);

# %%
#Checking to see that I have all of the columns I need
raw_internet_demos_all.head(3)
# Out:
#          geoid                             qualifying name  \
# 0  17031010100     Census Tract 101, Cook County, Illinois
# 1  17031010201  Census Tract 102.01, Cook County, Illinois
# 2  17031010202  Census Tract 102.02, Cook County, Illinois
#
#    Total: With An Internet Subscription  \
# 0                                1952.0
# 1                                2543.0
# 2                                1040.0
#
#    Total: With An Internet Subscription Dial-Up With No Other Type Of Internet Subscription  \
# 0                                               17.0
# 1                                                NaN
# 2                                                NaN
#
#    Total: With An Internet Subscription Broadband Of Any Type  \
# 0                                             1935.0
# 1                                             2543.0
# 2                                             1040.0
#
#    Total: With An Internet Subscription Cellular Data Plan  \
# 0                                             1761.0
# 1                                             2231.0
# 2                                              862.0
#
#    Total: With An Internet Subscription Cellular Data Plan Cellular Data Plan With No Other Type Of Internet Subscription  \
# 0                                              225.0
# 1                                              266.0
# 2                                              151.0
#
#    Total:  Broadband Such As Cable Fiber Optic Or Dsl  \
# 0                                             1710.0
# 1                                             2234.0
# 2                                              852.0
#
#    Total:  Broadband Such As Cable Fiber Optic Or Dsl Broadband Such As Cable Fiber Optic Or Dsl With No Other Type Of Internet Subscription  \
# 0                                              174.0
# 1                                              312.0
# 2                                              161.0
#
#    Total:  Satellite Internet Service  ...   Total  \
# 0                                62.0  ...  2411.0
# 1                               128.0  ...  2996.0
# 2                                56.0  ...  1234.0
#
#    Total: With An Internet Subscription Dial-Up Alone  \
# 0                                               17.0
# 1                                                NaN
# 2                                                NaN
#
#    Total: With An Internet Subscription Broadband Such As Cable Fiber Optic Or Dsl  \
# 0                                             1710.0
# 1                                             2234.0
# 2                                              852.0
#
#    Total: With An Internet Subscription Satellite Internet Service  \
# 0                                               62.0
# 1                                              128.0
# 2                                               56.0
#
#    Total: With An Internet Subscription Other Service  \
# 0                                                  0
# 1                                                 31
# 2                                                  0
#
#                                             geometry  \
# 0  POLYGON ((-87.676277 42.022965, -87.675968 42....
# 1  POLYGON ((-87.684317 42.019481, -87.683901 42....
# 2  POLYGON ((-87.676745 42.01941, -87.67651175102...
#
#    Percent of People with Internet Access  \
# 0                                0.846951
# 1                                0.903204
# 2                                0.890600
#
#    Percent of People without Internet Access  \
# 0                                   0.153049
# 1                                   0.096796
# 2                                   0.109400
#
#    Percent of People with Computers  Percent of People without Computers
# 0                          0.875985                             0.124015
# 1                          0.909880                             0.090120
# 2                          0.939222                             0.060778
#
# [3 rows x 29 columns]

# %% [markdown]
# ### Computer and Internet Access ###

# %%
#Replacing 0 values in total column with Nan
raw_internet_demo['Total'] = raw_internet_demo['Total'].replace(0,np.nan)

#Adding Column that calculates: (Has Computer w Internet + Has Computer w Internet)/(Total) = Percent of people who have a computer with internet
raw_internet_demo['Percent of People with Computers and Internet'] = (((raw_internet_demo['Total: Has A Computer: With Dial-Up Internet Subscription Alone'] + raw_internet_demo['Total: Has A Computer: With A Broadband Internet Subscription']))/(raw_internet_demo['Total']))
       
raw_internet_demo['Percent of People with Computers and Internet'] = pd.to_numeric(raw_internet_demo['Percent of People with Computers and Internet'])    
    
raw_internet_demo.head(2)
# Out:
#          geoid                             qualifying name  \
# 0  17031010100     Census Tract 101, Cook County, Illinois
# 1  17031010201  Census Tract 102.01, Cook County, Illinois
#
#   Total: With An Internet Subscription  \
# 0                                 1952
# 1                                 2543
#
#   Total: With An Internet Subscription Dial-Up With No Other Type Of Internet Subscription  \
# 0                                                 17
# 1                                                  0
#
#   Total: With An Internet Subscription Broadband Of Any Type  \
# 0                                               1935
# 1                                               2543
#
#   Total: With An Internet Subscription Cellular Data Plan  \
# 0                                               1761
# 1                                               2231
#
#   Total: With An Internet Subscription Cellular Data Plan Cellular Data Plan With No Other Type Of Internet Subscription  \
# 0                                                225
# 1                                                266
#
#   Total:  Broadband Such As Cable Fiber Optic Or Dsl  \
# 0                                               1710
# 1                                               2234
#
#   Total:  Broadband Such As Cable Fiber Optic Or Dsl Broadband Such As Cable Fiber Optic Or Dsl With No Other Type Of Internet Subscription  \
# 0                                                174
# 1                                                312
#
#   Total:  Satellite Internet Service  ...  \
# 0                                 62  ...
# 1                                128  ...
#
#   Total: Has A Computer: With A Broadband Internet Subscription  \
# 0                                               1870
# 1                                               2468
#
#   Total: Has A Computer: Without An Internet Subscription Total: No Computer  \
# 0                                                225                     299
# 1                                                258                     270
#
#     Total Total: With An Internet Subscription Dial-Up Alone  \
# 0  2411.0                                                 17
# 1  2996.0                                                  0
#
#   Total: With An Internet Subscription Broadband Such As Cable Fiber Optic Or Dsl  \
# 0                                               1710
# 1                                               2234
#
#   Total: With An Internet Subscription Satellite Internet Service  \
# 0                                                 62
# 1                                                128
#
#   Total: With An Internet Subscription Other Service  \
# 0                                                  0
# 1                                                 31
#
#                                             geometry  \
# 0  POLYGON ((-87.676277 42.022965, -87.675968 42....
# 1  POLYGON ((-87.684317 42.019481, -87.683901 42....
#
#    Percent of People with Computers and Internet
# 0                                       0.782663
# 1                                       0.823765
#
# [2 rows x 26 columns]

# %%
raw_internet_demo['Total']

# %%
raw_internet_demo.loc[0,'Percent of People with Computers and Internet'].dtype

# %%
#Reading in clean branch data
branchLocsOnly = pd.read_csv('../../data/clean/branches.csv')

# this line makes a copy of the raw_internet_demos_all data frame so we can manipulate without affecting our primary dataset
CandI_access_percentage = raw_internet_demo.copy(deep = True)

# the following converts the data frame to a geo data frame and plots Percentage of People with Internet Access
CandI_access_percentage = gpd.GeoDataFrame(
    CandI_access_percentage.loc[:, [c for c in CandI_access_percentage.columns if c != "geometry"]],
    geometry=gpd.GeoSeries.from_wkt(CandI_access_percentage["geometry"]),
    crs="epsg:4326",
    )

fig, ax = plt.subplots(1, figsize=(6, 6))
base = CandI_access_percentage.plot(column='Percent of People with Computers and Internet',legend=True, ax=ax, cmap='inferno')
ax.axis('off')
ax.set_title('Percent of People with Computers and Internet', fontdict={'fontsize': '12', 'fontweight' : '3'})

#Adding small white dots to represent library branch points
branchLocsOnly.crs = 'EPSG:4326'
branchLocsOnly[['Latitude', 'Longitude']] = [ast.literal_eval(x)[:2] for x in branchLocsOnly['LOCATION']]
branchLocsOnly = branchLocsOnly.drop(columns='LOCATION')


branchLocsOnly = gpd.GeoDataFrame(
    branchLocsOnly, geometry=gpd.points_from_xy(branchLocsOnly.Longitude, branchLocsOnly.Latitude), crs="EPSG:4326")


branchLocsOnly.plot(ax=base, marker='o', color='white', markersize=5);

# %%
raw_internet_demo.head(1)
# Out:
#          geoid                          qualifying name  \
# 0  17031010100  Census Tract 101, Cook County, Illinois
#
#   Total: With An Internet Subscription  \
# 0                                 1952
#
#   Total: With An Internet Subscription Dial-Up With No Other Type Of Internet Subscription  \
# 0                                                 17
#
#   Total: With An Internet Subscription Broadband Of Any Type  \
# 0                                               1935
#
#   Total: With An Internet Subscription Cellular Data Plan  \
# 0                                               1761
#
#   Total: With An Internet Subscription Cellular Data Plan Cellular Data Plan With No Other Type Of Internet Subscription  \
# 0                                                225
#
#   Total:  Broadband Such As Cable Fiber Optic Or Dsl  \
# 0                                               1710
#
#   Total:  Broadband Such As Cable Fiber Optic Or Dsl Broadband Such As Cable Fiber Optic Or Dsl With No Other Type Of Internet Subscription  \
# 0                                                174
#
#   Total:  Satellite Internet Service  ...  \
# 0                                 62  ...
#
#   Total: Has A Computer: With A Broadband Internet Subscription  \
# 0                                               1870
#
#   Total: Has A Computer: Without An Internet Subscription Total: No Computer  \
# 0                                                225                     299
#
#     Total Total: With An Internet Subscription Dial-Up Alone  \
# 0  2411.0                                                 17
#
#   Total: With An Internet Subscription Broadband Such As Cable Fiber Optic Or Dsl  \
# 0                                               1710
#
#   Total: With An Internet Subscription Satellite Internet Service  \
# 0                                                 62
#
#   Total: With An Internet Subscription Other Service  \
# 0                                                  0
#
#                                             geometry  \
# 0  POLYGON ((-87.676277 42.022965, -87.675968 42....
#
#    Percent of People with Computers and Internet
# 0                                       0.782663
#
# [1 rows x 26 columns]

# %%
raw_internet_demos_all.head(1)
# Out:
#          geoid                          qualifying name  \
# 0  17031010100  Census Tract 101, Cook County, Illinois
#
#    Total: With An Internet Subscription  \
# 0                                1952.0
#
#    Total: With An Internet Subscription Dial-Up With No Other Type Of Internet Subscription  \
# 0                                               17.0
#
#    Total: With An Internet Subscription Broadband Of Any Type  \
# 0                                             1935.0
#
#    Total: With An Internet Subscription Cellular Data Plan  \
# 0                                             1761.0
#
#    Total: With An Internet Subscription Cellular Data Plan Cellular Data Plan With No Other Type Of Internet Subscription  \
# 0                                              225.0
#
#    Total:  Broadband Such As Cable Fiber Optic Or Dsl  \
# 0                                             1710.0
#
#    Total:  Broadband Such As Cable Fiber Optic Or Dsl Broadband Such As Cable Fiber Optic Or Dsl With No Other Type Of Internet Subscription  \
# 0                                              174.0
#
#    Total:  Satellite Internet Service  ...   Total  \
# 0                                62.0  ...  2411.0
#
#    Total: With An Internet Subscription Dial-Up Alone  \
# 0                                               17.0
#
#    Total: With An Internet Subscription Broadband Such As Cable Fiber Optic Or Dsl  \
# 0                                             1710.0
#
#    Total: With An Internet Subscription Satellite Internet Service  \
# 0                                               62.0
#
#    Total: With An Internet Subscription Other Service  \
# 0                                                  0
#
#                                             geometry  \
# 0  POLYGON ((-87.676277 42.022965, -87.675968 42....
#
#    Percent of People with Internet Access  \
# 0                                0.846951
#
#    Percent of People without Internet Access  \
# 0                                   0.153049
#
#    Percent of People with Computers  Percent of People without Computers
# 0                          0.875985                             0.124015
#
# [1 rows x 29 columns]

# %%
#Adding Percent of People with Computers and Internet from raw_internet_demos_all into raw_internet_demo
raw_internet_demos_all['Percent of People with Computers and Internet'] = raw_internet_demo['Percent of People with Computers and Internet']
raw_internet_demos_all
# Out:
#            geoid                                qualifying name  \
# 0    17031010100        Census Tract 101, Cook County, Illinois
# 1    17031010201     Census Tract 102.01, Cook County, Illinois
# 2    17031010202     Census Tract 102.02, Cook County, Illinois
# 3    17031010300        Census Tract 103, Cook County, Illinois
# 4    17031010400        Census Tract 104, Cook County, Illinois
# ..           ...                                            ...
# 864  17031980100       Census Tract 9801, Cook County, Illinois
# 865  17031990000       Census Tract 9900, Cook County, Illinois
# 866  17043840000     Census Tract 8400, DuPage County, Illinois
# 867  17043840801  Census Tract 8408.01, DuPage County, Illinois
# 868  17043840802  Census Tract 8408.02, DuPage County, Illinois
#
#      Total: With An Internet Subscription  \
# 0                                  1952.0
# 1                                  2543.0
# 2                                  1040.0
# 3                                  2548.0
# 4                                  1487.0
# ..                                    ...
# 864                                   NaN
# 865                                   NaN
# 866                                 818.0
# 867                                 642.0
# 868                                1981.0
#
#      Total: With An Internet Subscription Dial-Up With No Other Type Of Internet Subscription  \
# 0                                                 17.0
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 864                                                NaN
# 865                                                NaN
# 866                                                6.0
# 867                                                NaN
# 868                                                NaN
#
#      Total: With An Internet Subscription Broadband Of Any Type  \
# 0                                               1935.0
# 1                                               2543.0
# 2                                               1040.0
# 3                                               2548.0
# 4                                               1487.0
# ..                                                 ...
# 864                                                NaN
# 865                                                NaN
# 866                                              812.0
# 867                                              642.0
# 868                                             1981.0
#
#      Total: With An Internet Subscription Cellular Data Plan  \
# 0                                               1761.0
# 1                                               2231.0
# 2                                                862.0
# 3                                               2320.0
# 4                                               1423.0
# ..                                                 ...
# 864                                                NaN
# 865                                                NaN
# 866                                              778.0
# 867                                              566.0
# 868                                             1926.0
#
#      Total: With An Internet Subscription Cellular Data Plan Cellular Data Plan With No Other Type Of Internet Subscription  \
# 0                                                225.0
# 1                                                266.0
# 2                                                151.0
# 3                                                352.0
# 4                                                216.0
# ..                                                 ...
# 864                                                NaN
# 865                                                NaN
# 866                                               81.0
# 867                                               47.0
# 868                                              283.0
#
#      Total:  Broadband Such As Cable Fiber Optic Or Dsl  \
# 0                                               1710.0
# 1                                               2234.0
# 2                                                852.0
# 3                                               2112.0
# 4                                               1238.0
# ..                                                 ...
# 864                                                NaN
# 865                                                NaN
# 866                                              681.0
# 867                                              575.0
# 868                                             1594.0
#
#      Total:  Broadband Such As Cable Fiber Optic Or Dsl Broadband Such As Cable Fiber Optic Or Dsl With No Other Type Of Internet Subscription  \
# 0                                                174.0
# 1                                                312.0
# 2                                                161.0
# 3                                                185.0
# 4                                                 64.0
# ..                                                 ...
# 864                                                NaN
# 865                                                NaN
# 866                                               16.0
# 867                                               71.0
# 868                                               55.0
#
#      Total:  Satellite Internet Service  ...  \
# 0                                  62.0  ...
# 1                                 128.0  ...
# 2                                  56.0  ...
# 3                                 183.0  ...
# 4                                  47.0  ...
# ..                                  ...  ...
# 864                                 NaN  ...
# 865                                 NaN  ...
# 866                               134.0  ...
# 867                                34.0  ...
# 868                               338.0  ...
#
#      Total: With An Internet Subscription Dial-Up Alone  \
# 0                                                 17.0
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 864                                                NaN
# 865                                                NaN
# 866                                                6.0
# 867                                                NaN
# 868                                                NaN
#
#      Total: With An Internet Subscription Broadband Such As Cable Fiber Optic Or Dsl  \
# 0                                               1710.0
# 1                                               2234.0
# 2                                                852.0
# 3                                               2112.0
# 4                                               1238.0
# ..                                                 ...
# 864                                                NaN
# 865                                                NaN
# 866                                              681.0
# 867                                              575.0
# 868                                             1594.0
#
#      Total: With An Internet Subscription Satellite Internet Service  \
# 0                                                 62.0
# 1                                                128.0
# 2                                                 56.0
# 3                                                183.0
# 4                                                 47.0
# ..                                                 ...
# 864                                                NaN
# 865                                                NaN
# 866                                              134.0
# 867                                               34.0
# 868                                              338.0
#
#      Total: With An Internet Subscription Other Service  \
# 0                                                    0
# 1                                                   31
# 2                                                    0
# 3                                                  100
# 4                                                    0
# ..                                                 ...
# 864                                                  0
# 865                                                  0
# 866                                                  0
# 867                                                  5
# 868                                                 67
#
#                                               geometry  \
# 0    POLYGON ((-87.676277 42.022965, -87.675968 42....
# 1    POLYGON ((-87.684317 42.019481, -87.683901 42....
# 2    POLYGON ((-87.676745 42.01941, -87.67651175102...
# 3    POLYGON ((-87.671212 42.019373, -87.670858 42....
# 4    POLYGON ((-87.663213 42.012834, -87.662494 42....
# ..                                                 ...
# 864  POLYGON ((-87.762058 41.792739, -87.761701 41....
# 865  MULTIPOLYGON (((-87.609113 41.888267, -87.6054...
# 866  POLYGON ((-87.938967 41.993515, -87.938927 41....
# 867  MULTIPOLYGON (((-87.939058 41.958485, -87.9390...
# 868  POLYGON ((-87.939284 41.960893, -87.939229 41....
#
#      Percent of People with Internet Access  \
# 0                                  0.846951
# 1                                  0.903204
# 2                                  0.890600
# 3                                  0.877462
# 4                                  0.779744
# ..                                      ...
# 864                                     NaN
# 865                                     NaN
# 866                                0.872999
# 867                                0.696653
# 868                                0.917554
#
#      Percent of People without Internet Access  \
# 0                                     0.153049
# 1                                     0.096796
# 2                                     0.109400
# 3                                     0.122538
# 4                                     0.220256
# ..                                         ...
# 864                                        NaN
# 865                                        NaN
# 866                                   0.127001
# 867                                   0.303347
# 868                                   0.082446
#
#      Percent of People with Computers  Percent of People without Computers  \
# 0                            0.875985                             0.124015
# 1                            0.909880                             0.090120
# 2                            0.939222                             0.060778
# 3                            0.946578                             0.053422
# 4                            0.823009                             0.176991
# ..                                ...                                  ...
# 864                               NaN                                  NaN
# 865                               NaN                                  NaN
# 866                          0.923159                             0.076841
# 867                          0.688285                             0.311715
# 868                          0.941640                             0.058360
#
#      Percent of People with Computers and Internet
# 0                                         0.782663
# 1                                         0.823765
# 2                                         0.828201
# 3                                         0.837396
# 4                                         0.731072
# ..                                             ...
# 864                                            NaN
# 865                                            NaN
# 866                                       0.866596
# 867                                       0.648536
# 868                                       0.905049
#
# [869 rows x 30 columns]

# %% [markdown]
# ## Combining all info for CSV file

# %%
internet_demos = raw_internet_demos_all[['geoid',
                                         'qualifying name',
                                         'geometry',
                                         'Total',
                                         'Percent of People with Internet Access',
                                         'Percent of People without Internet Access',
                                         'Percent of People with Computers',
                                         'Percent of People without Computers',
                                         'Percent of People with Computers and Internet']]

# %%
internet_demos.set_index('geoid',inplace=True)
internet_demos
# Out:
#                                            qualifying name  \
# geoid
# 17031010100        Census Tract 101, Cook County, Illinois
# 17031010201     Census Tract 102.01, Cook County, Illinois
# 17031010202     Census Tract 102.02, Cook County, Illinois
# 17031010300        Census Tract 103, Cook County, Illinois
# 17031010400        Census Tract 104, Cook County, Illinois
# ...                                                    ...
# 17031980100       Census Tract 9801, Cook County, Illinois
# 17031990000       Census Tract 9900, Cook County, Illinois
# 17043840000     Census Tract 8400, DuPage County, Illinois
# 17043840801  Census Tract 8408.01, DuPage County, Illinois
# 17043840802  Census Tract 8408.02, DuPage County, Illinois
#
#                                                       geometry   Total  \
# geoid
# 17031010100  POLYGON ((-87.676277 42.022965, -87.675968 42....  2411.0
# 17031010201  POLYGON ((-87.684317 42.019481, -87.683901 42....  2996.0
# 17031010202  POLYGON ((-87.676745 42.01941, -87.67651175102...  1234.0
# 17031010300  POLYGON ((-87.671212 42.019373, -87.670858 42....  2995.0
# 17031010400  POLYGON ((-87.663213 42.012834, -87.662494 42....  2034.0
# ...                                                        ...     ...
# 17031980100  POLYGON ((-87.762058 41.792739, -87.761701 41....     NaN
# 17031990000  MULTIPOLYGON (((-87.609113 41.888267, -87.6054...     NaN
# 17043840000  POLYGON ((-87.938967 41.993515, -87.938927 41....   937.0
# 17043840801  MULTIPOLYGON (((-87.939058 41.958485, -87.9390...   956.0
# 17043840802  POLYGON ((-87.939284 41.960893, -87.939229 41....  2159.0
#
#              Percent of People with Internet Access  \
# geoid
# 17031010100                                0.846951
# 17031010201                                0.903204
# 17031010202                                0.890600
# 17031010300                                0.877462
# 17031010400                                0.779744
# ...                                             ...
# 17031980100                                     NaN
# 17031990000                                     NaN
# 17043840000                                0.872999
# 17043840801                                0.696653
# 17043840802                                0.917554
#
#              Percent of People without Internet Access  \
# geoid
# 17031010100                                   0.153049
# 17031010201                                   0.096796
# 17031010202                                   0.109400
# 17031010300                                   0.122538
# 17031010400                                   0.220256
# ...                                                ...
# 17031980100                                        NaN
# 17031990000                                        NaN
# 17043840000                                   0.127001
# 17043840801                                   0.303347
# 17043840802                                   0.082446
#
#              Percent of People with Computers  \
# geoid
# 17031010100                          0.875985
# 17031010201                          0.909880
# 17031010202                          0.939222
# 17031010300                          0.946578
# 17031010400                          0.823009
# ...                                       ...
# 17031980100                               NaN
# 17031990000                               NaN
# 17043840000                          0.923159
# 17043840801                          0.688285
# 17043840802                          0.941640
#
#              Percent of People without Computers  \
# geoid
# 17031010100                             0.124015
# 17031010201                             0.090120
# 17031010202                             0.060778
# 17031010300                             0.053422
# 17031010400                             0.176991
# ...                                          ...
# 17031980100                                  NaN
# 17031990000                                  NaN
# 17043840000                             0.076841
# 17043840801                             0.311715
# 17043840802                             0.058360
#
#              Percent of People with Computers and Internet
# geoid
# 17031010100                                       0.782663
# 17031010201                                       0.823765
# 17031010202                                       0.828201
# 17031010300                                       0.837396
# 17031010400                                       0.731072
# ...                                                    ...
# 17031980100                                            NaN
# 17031990000                                            NaN
# 17043840000                                       0.866596
# 17043840801                                       0.648536
# 17043840802                                       0.905049
#
# [869 rows x 8 columns]

# %%
internet_demos.to_csv('../../data/final data/internet_demos.csv')
